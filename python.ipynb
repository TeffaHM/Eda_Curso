# %% [markdown]
# # Python Review#

# %% [markdown]
# ## Lesson 1 ##
#
# * Variables as the first Data managament.
# * Data Structutes are the next level in Data Management.
# * Mutability and Inmutability. You should use almost tuples.
# * Sets vs Lists in searching

# %%
number_int = 10
number_float = 10.5
print(type(number_int))
print(type(number_float))
# Out:
# <class 'int'>
# <class 'float'>

# %%
# We have defined n as size the list.
# thousand_n contains thousand values equal to n-1.

n = 1000000
thousand_n = [n - 1] * 1000

# %%
# %%time

lst = [i for i in range(n)]
for x in thousand_n:
    x in lst
# Out:
# CPU times: total: 12.5 s
# Wall time: 12.7 s

# %%
# %%time

s = {i for i in range(n)}
for x in thousand_n:
    x in s
# Out:
# CPU times: user 60.8 ms, sys: 50.3 ms, total: 111 ms
# Wall time: 113 ms

# %% [markdown]
# ## Lesson 2 ##
#
# * Dictionaries are hash tables.
# * Newly mutability and inmutability
# * Now yes? POO and objects.

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### Primes

# %% [markdown]
# Given a number `n`, if it's prime print `True` if not print `False`
#
# #### Examples:
#
# ```
# n = 20:
#
# False
#
# n = 23:
#
# True
# ```

# %% [markdown]
# ### 2n - 1
#
# Given a number `n`, print a asterisk rhombus pattern with `2n-1` levels.
#
# ##### Ejemplos:
#
# `n = 1:`
# ```
#    *
# ```
#
# `n = 2:`
# ```
#    *
#   ***
#    *
# ```
#
# `n = 3:`
# ```
#    *
#   ***
#  *****
#   ***
#    *
# ```

# %% [markdown]
# ## Lesson 3

# %% [markdown]
# ### Exercises:
#
# * Assay_df
# *
# *
